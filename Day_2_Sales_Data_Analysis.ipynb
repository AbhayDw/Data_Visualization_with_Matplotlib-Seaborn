# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
data={"product":["Leptop","Mobile","Tablet","Mobile","Leptop"],
      "amount":[65000,20000,26000,12000,45000],
      "city":["Bhopal","Indore","Delhi","Satna","Bhopal"]}
df=pd.DataFrame(data)
df
# Out:
#   product  amount    city
# 0  Leptop   65000  Bhopal
# 1  Mobile   20000  Indore
# 2  Tablet   26000   Delhi
# 3  Mobile   12000   Satna
# 4  Leptop   45000  Bhopal

# %%
Total_revenue=df.sum()
Total_revenue
# Out:
# product    LeptopMobileTabletMobileLeptop
# amount                             168000
# city         BhopalIndoreDelhiSatnaBhopal
# dtype: object

# %%
df.value_counts()
# Out:
# product  amount  city
# Leptop   45000   Bhopal    1
#          65000   Bhopal    1
# Mobile   12000   Satna     1
#          20000   Indore    1
# Tablet   26000   Delhi     1
# Name: count, dtype: int64

# %%
print("Top Product:", df.groupby('product')['amount'].sum().idxmax())
# Out:
# Top Product: Leptop

# %%
df["amount"].sum()
# Out:
# np.int64(168000)

# %%
#graph
df.groupby("city")["amount"].sum().plot.bar()
plt.show()

# %%
df.to_csv("sales.csv", index=False)

# %%
df=pd.read_csv('/content/sales.csv')
df
# Out:
#   product  amount    city
# 0  Leptop   65000  Bhopal
# 1  Mobile   20000  Indore
# 2  Tablet   26000   Delhi
# 3  Mobile   12000   Satna
# 4  Leptop   45000  Bhopal
